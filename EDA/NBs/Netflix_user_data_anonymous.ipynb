# %% [markdown]
# # About Dataset
# The dataset provides a snapshot of a sample Netflix userbase, showcasing various aspects of user subscriptions, revenue, account details, and activity. Each row represents a unique user, identified by their User ID. The dataset includes information such as the user's subscription type (Basic, Standard, or Premium), the monthly revenue generated from their subscription, the date they joined Netflix (Join Date), the date of their last payment (Last Payment Date), and the country in which they are located.
#
# Additional columns have been included to provide insights into user behavior and preferences. These columns include Device Type (e.g., Smart TV, Mobile, Desktop, Tablet) and Account Status (whether the account is active or not). The dataset serves as a synthetic representation and does not reflect actual Netflix user data. It can be used for analysis and modeling to understand user trends, preferences, and revenue generation within a hypothetical Netflix userbase.
#
# Source: [Kaggle](https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset?resource=download)

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
# !wget https://github.com/Ben-physics-dotcom/Data-Science-Projects/raw/main/EDA/Data/Netflix.zip
# !unzip Netflix.zip

# %%
df = pd.read_csv('/content/Netflix Userbase.csv')

# %% [markdown]
# # EDA

# %%
print(len(df))
df.head()
# Out:
# 2500
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %% [markdown]
# ## Histograms

# %%
lst = ['Subscription Type','Monthly Revenue',
       'Country','Age','Gender','Device','Plan Duration']
for i in lst:
  df[i].hist(grid=False)
  plt.ylabel('Counts')
  plt.title(i)
  plt.xticks(rotation=60)
  plt.show()

# %% [markdown]
# An interpretation could be that the focus for Netflix should be on the `Basic` account version in the countries Spain, US and Canada.

# %% [markdown]
# ## first overview

# %%
for i in ['Country','Device','Gender']:
  plt.scatter(df[i],df['Age'])
  plt.ylabel('Age')
  plt.xticks(rotation=90)
  plt.show()

# %% [markdown]
# A scatter plot doesn't make a great job for this kind of data representation. The best way to plot the data is with boxplots.

# %% [markdown]
# ## Box Plots

# %%
# Test
df.boxplot(column=['Age'],by='Gender')
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Gender'>

# %%
# result
for i in ['Country','Device','Gender','Monthly Revenue']:
  df.boxplot(column=['Age'],by=i)
  plt.title(f'{i}')
  plt.ylabel('Age')
  plt.xticks(rotation=90)
  plt.show()
